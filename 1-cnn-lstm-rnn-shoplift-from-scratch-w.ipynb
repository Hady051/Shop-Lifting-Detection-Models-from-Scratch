# %% [markdown]
# ## This Note Loads the dataset and does the augmentations on RAM (on memory) unlike the other ones.

# %% [markdown]
# ---

# %% [markdown]
# # PART 1: IMPORT LIBRARIES AND MOUNT GOOGLE DRIVE

# %%
import os
import zipfile
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tqdm import tqdm

# %% [markdown]
# `tqdm` is used to show **progress bars** during loops.
#
# It's used when:
# * Finding minimum frames (PART 4) - Shows progress while scanning all videos
# * Loading videos (PART 5) - Shows progress while loading non-shoplifter and shoplifter videos
# * Applying augmentation (PART 9) - Shows progress while augmenting the training data

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
print("Libraries imported and Drive mounted successfully!")
# Out:
# Libraries imported and Drive mounted successfully!

# %% [markdown]
# ___
#
# # PART 2: EXTRACT ZIP FILE AND SET PATHS

# %%
# ZIP_PATH = '/content/drive/MyDrive/Colab Notebooks/Cellula Tech Intern Computer Vision/Task 6: Shop Lifting Detection models from scratch/Shop DataSet.zip'
# EXTRACT_PATH = '/content/shop_data'

# %% [markdown]
# ### Extract zip file from Google Drive

# %%
# def extract_zip_file(zip_path, extract_path):
#     if not os.path.exists(extract_path):
#         os.makedirs(extract_path)
#         print(f"Extracting {zip_path}...")
#         with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#             zip_ref.extractall(extract_path)
#         print("Extraction complete!")
#     else:
#         print("Data already extracted!")

#     # List contents (top level only, break will stop after top level search)
#     for root, dirs, files in os.walk(extract_path):
#         print(f"\nDirectory: {root}")
#         print(f"Subdirectories: {dirs}")
#         print(f"Files count: {len(files)}")
#         break

# %%
# extract_zip_file(ZIP_PATH, EXTRACT_PATH)

# %% [markdown]
# ### DEBUG: Find actual folder structure

# %%
# print("Exploring extracted contents...")
# for root, dirs, files in os.walk(EXTRACT_PATH):
#     level = root.replace(EXTRACT_PATH, '').count(os.sep)
#     indent = ' ' * 2 * level
#     print(f'{indent}{os.path.basename(root)}/')
#     subindent = ' ' * 2 * (level + 1)
#     for file in files[:5]:  # Show first 5 files
#         print(f'{subindent}{file}')
#     if len(files) > 5:
#         print(f'{subindent}... and {len(files)-5} more files')

# %% [markdown]
# ### Set dataset paths

# %%
## Kaggle

DATASET_PATH = '/kaggle/input/shop-lifting-dataset/Shop DataSet'
NON_SHOPLIFTERS_PATH = os.path.join(DATASET_PATH, 'non shop lifters')
SHOPLIFTERS_PATH = os.path.join(DATASET_PATH, 'shop lifters')

# %% [markdown]
# ---
#
# # PART 3: CONFIGURATION AND HYPERPARAMETERS

# %%
## Video processing parameters
# IMG_HEIGHT = 128
# IMG_WIDTH = 128
IMG_HEIGHT = 64
IMG_WIDTH = 64

NUM_FRAMES = 50
# NUM_FRAMES = 75  # Number of frames to extract from each video (from the min frames function)

CHANNELS = 3

# %%
## Training parameters
BATCH_SIZE = 4

# EPOCHS = 100
EPOCHS = 50

LEARNING_RATE = 0.001

# %%
## Class labels, Multi-classification
CLASS_NAMES = ['non_shoplifter', 'shoplifter']
NUM_CLASSES = len(CLASS_NAMES)

# %%
# NUM_CLASSES = 1  # Binary classification (non-shoplifter or shoplifter)

# %%
print("Configuration set: \n")
print(f"Image size: {IMG_HEIGHT}x{IMG_WIDTH}")
print(f"Frames per video: {NUM_FRAMES}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Classes: {CLASS_NAMES}")
# Out:
# Configuration set:
#
# Image size: 64x64
# Frames per video: 50
# Batch size: 4
# Classes: ['non_shoplifter', 'shoplifter']

# %% [markdown]
# ___
#
# # PART 4: FIND MINIMUM FRAMES IN DATASET

# %% [markdown]
# **Find the video with the fewest number of frames in the entire dataset**

# %%
def find_minimum_frames(non_shoplifters_path, shoplifters_path):
    min_frames = float('inf')
    min_video_path = None

    print("Scanning non-shoplifter videos...")
    non_shoplifter_files = [f for f in os.listdir(non_shoplifters_path)
                            if f.endswith(('.mp4', '.avi', '.mov', '.mkv'))]

    for video_file in tqdm(non_shoplifter_files):
        video_path = os.path.join(non_shoplifters_path, video_file)
        cap = cv2.VideoCapture(video_path)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        cap.release()

        if total_frames > 0 and total_frames < min_frames:
            min_frames = total_frames
            min_video_path = video_path

    print("Scanning shoplifter videos...")
    shoplifter_files = [f for f in os.listdir(shoplifters_path)
                        if f.endswith(('.mp4', '.avi', '.mov', '.mkv'))]

    for video_file in tqdm(shoplifter_files):
        video_path = os.path.join(shoplifters_path, video_file)
        cap = cv2.VideoCapture(video_path)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        cap.release()

        if total_frames > 0 and total_frames < min_frames:
            min_frames = total_frames
            min_video_path = video_path

    print(f"\n{'='*60}")
    print(f"Minimum frames in dataset: {min_frames}")
    print(f"Video path: {min_video_path}")
    print('='*60)

    return min_frames, min_video_path

# %%
## Find minimum frames
min_frames, min_video_path = find_minimum_frames(NON_SHOPLIFTERS_PATH, SHOPLIFTERS_PATH)
# Out:
# Scanning non-shoplifter videos...
# 100%|██████████| 531/531 [00:03<00:00, 136.21it/s]
# Scanning shoplifter videos...
# 100%|██████████| 324/324 [00:03<00:00, 87.34it/s]
# ============================================================
# Minimum frames in dataset: 75
# Video path: /kaggle/input/shop-lifting-dataset/Shop DataSet/non shop lifters/shop_lifter_n_215_1.mp4
# ============================================================

# %% [markdown]
# ---
#
# # PART 5: Video Preprocessing Functions

# %% [markdown]
# ### Extract fixed number of frames from video with temporal sampling

# %%
def extract_frames_from_video(video_path, num_frames=NUM_FRAMES):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames == 0:
        cap.release()
        return None

    # Calculate frame indices to extract (evenly spaced)
    frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)

    frames = []
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            # Resize and normalize
            frame = cv2.resize(frame, (IMG_WIDTH, IMG_HEIGHT))
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
        else:
            # If frame reading fails, use black frame
            # frames.append(np.zeros((IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8))
            print(f"Failed to read frame at index {idx} from video {video_path}")
            break

    cap.release()

    # Ensure we have exactly num_frames
    while len(frames) < num_frames:
        frames.append(frames[-1] if frames else np.zeros((IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8))

    return np.array(frames[:num_frames])

# %% [markdown]
# ### Normalize Frames

# %%
def normalize_frames(frames):
    return frames.astype(np.float32) / 255.0

# %% [markdown]
# ### Complete preprocessing pipeline for a single video

# %%
def preprocess_video(video_path):
    frames = extract_frames_from_video(video_path)
    if frames is None:
        return None
    frames = normalize_frames(frames)
    return frames

# %% [markdown]
# ---
#
# # PART 5: LOAD DATASET

# %% [markdown]
# ### Load all videos and their labels from both directories

# %%
def load_video_dataset(non_shoplifters_path, shoplifters_path):
    videos = []
    labels = []

    print("Loading non-shoplifter videos...")
    non_shoplifter_files = [f for f in os.listdir(non_shoplifters_path)
                            if f.endswith(('.mp4', '.avi', '.mov', '.mkv'))]

    for video_file in tqdm(non_shoplifter_files):
        video_path = os.path.join(non_shoplifters_path, video_file)
        frames = preprocess_video(video_path)
        if frames is not None:
            videos.append(frames)
            labels.append(0)  # 0 for non-shoplifter

    print(f"\nLoading shoplifter videos...")
    shoplifter_files = [f for f in os.listdir(shoplifters_path)
                        if f.endswith(('.mp4', '.avi', '.mov', '.mkv'))]

    for video_file in tqdm(shoplifter_files):
        video_path = os.path.join(shoplifters_path, video_file)
        frames = preprocess_video(video_path)
        if frames is not None:
            videos.append(frames)
            labels.append(1)  # 1 for shoplifter

    videos = np.array(videos)
    labels = np.array(labels)

    print("\nDataset loaded successfully!\n")
    print(f"Total videos: {len(videos)}")
    print(f"Non-shoplifters: {np.sum(labels == 0)}")
    print(f"Shoplifters: {np.sum(labels == 1)}")
    print(f"Video shape: {videos.shape}")

    return videos, labels

# %%
# Load the dataset
# X, y = load_video_dataset(NON_SHOPLIFTERS_PATH, SHOPLIFTERS_PATH)
videos, labels = load_video_dataset(NON_SHOPLIFTERS_PATH, SHOPLIFTERS_PATH)
# Out:
# Loading non-shoplifter videos...
# 100%|██████████| 531/531 [09:03<00:00,  1.02s/it]
# Loading shoplifter videos...
# 100%|██████████| 324/324 [12:22<00:00,  2.29s/it]
# Dataset loaded successfully!
#
# Total videos: 855
# Non-shoplifters: 531
# Shoplifters: 324
# Video shape: (855, 50, 64, 64, 3)

# %% [markdown]
# ---
#
# # PART 6: TRAIN-TEST SPLIT

# %%
# Split data into train and test sets (80-20 split)
videos_train, videos_test, labels_train, labels_test = train_test_split(
    videos, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Training set: {videos_train.shape[0]} videos")
print(f"Test set: {videos_test.shape[0]} videos")
print(f"Training non-shoplifters: {np.sum(labels_train == 0)}")
print(f"Training shoplifters: {np.sum(labels_train == 1)}")
print(f"Test non-shoplifters: {np.sum(labels_test == 0)}")
print(f"Test shoplifters: {np.sum(labels_test == 1)}")
# Out:
# Training set: 684 videos
# Test set: 171 videos
# Training non-shoplifters: 425
# Training shoplifters: 259
# Test non-shoplifters: 106
# Test shoplifters: 65

# %% [markdown]
# The `stratify=labels` parameter in the `train_test_split` function ensures that the split is performed in a way that maintains the same proportion of classes in both the training and testing sets as in the original dataset.
#
# This is particularly important when dealing with imbalanced datasets, where one class is significantly more represented than others.
#
# It helps to prevent the model from being biased towards the majority class.

# %% [markdown]
# ---
#
# # PART 7: AUGMENTATION FUNCTIONS - INDIVIDUAL PREVIEW

# %%
import albumentations as A

# %% [markdown]
# ### Create Albumentations Pipeline

# %%
def get_augmentation_pipeline():
    """Create Albumentations pipeline for spatial augmentations"""
    return A.ReplayCompose([
        A.HorizontalFlip(p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.1, p=0.4),
        # A.Rotate(limit=15, p=0.3),
        
        # Removed A.RandomScale - it changes image dimensions
        # Using ShiftScaleRotate instead which maintains size
        A.ShiftScaleRotate(
            shift_limit=0.1,
            scale_limit=0.1,
            rotate_limit=0,  # Rotation already handled above
            border_mode=cv2.BORDER_CONSTANT,
            p=0.3
        ),
    ])

# %% [markdown]
# #### E:

# %% [markdown]
# `p=1.0` for individual Augmentation Technique Visualization

# %% [markdown]
# Uses `ReplayCompose` to apply same transformation to **all frames** in the video.
#
# `ReplayCompose` in general is used when dealing with **videos**.

# %% [markdown]
# ### Temporal crop - not in albumentations, manual implementation

# %%
# def augment_temporal_crop(frames, crop_ratio=0.95):
#     """
#     Temporal augmentation - crop and resample video
#     **GUARANTEES output has same length as input
#     """
#     num_frames = len(frames)
#     crop_length = max(1, int(num_frames * crop_ratio))  # Ensure at least 1 frame

#     if crop_length >= num_frames:
#         return frames  # No cropping needed

#     start_idx = np.random.randint(0, num_frames - crop_length + 1)
#     cropped = frames[start_idx:start_idx + crop_length]

#     # Resample back to original length
#     indices = np.linspace(0, len(cropped) - 1, num_frames, dtype=int)
#     return cropped[indices]

# %% [markdown]
# #### E:

# %% [markdown]
# **Why Use Temporal Crop?**
#
# It helps your model learn that **the exact timing of actions isn't fixed**, only **their visual pattern** matters.
#
# For example:
#
# * A shoplifter might reach for an item at frame 10 in one video and frame 20 in another.
#
# * Temporal cropping ensures your model doesn’t overfit to “where” in time the event occurs.
#
# So it introduces **temporal invariance** — the model becomes robust to when something happens in the sequence.

# %% [markdown]
# Step-by-step:
#
# 1. Takes, say, 30 frames (num_frames = 30).
#
# 2. Randomly selects 80% of them (crop_length = 24).
#
# 3. Chooses a random starting point (e.g., frame 5).
#
# 4. Extracts frames [F5 … F28].
#
# 5. Then stretches or samples back to 30 frames for model consistency.

# %% [markdown]
# ### Apply single Augmentation for Visualization

# %%
def apply_single_augmentation(frames, aug_name):
    """Apply single augmentation with p=1.0"""
    frames_uint8 = (frames * 255).astype(np.uint8)

    if aug_name == 'Horizontal Flip':
        transform = A.HorizontalFlip(p=1.0)
    elif aug_name == 'Brightness':
        transform = A.RandomBrightnessContrast(brightness_limit=0.3, p=1.0)
    # elif aug_name == 'Rotation':
        # transform = A.Rotate(limit=15, p=1.0)
    elif aug_name == 'Zoom':
        transform = A.RandomScale(scale_limit=0.2, p=1.0)
    # elif aug_name == 'Temporal Crop':
        # return augment_temporal_crop(frames, crop_ratio=0.95)

    # Apply same transform to all frames using ReplayCompose
    replay_transform = A.ReplayCompose([transform])
    data = replay_transform(image=frames_uint8[0])

    augmented = []
    for frame in frames_uint8:
        aug_frame = A.ReplayCompose.replay(data['replay'], image=frame)
        augmented.append(aug_frame['image'].astype(np.float32) / 255.0)

    return np.array(augmented)

# %%
def preview_individual_augmentations(X_train, num_samples=3):
    """Preview each augmentation separately"""
    augmentations = ['Horizontal Flip', 'Brightness', 'Zoom']

    for aug_name in augmentations:
        print(f"\n{'='*60}")
        print(f"Augmentation: {aug_name}")
        print('='*60)

        fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 3))

        for i in range(num_samples):
            idx = np.random.randint(0, len(X_train))
            original = X_train[idx]
            augmented = apply_single_augmentation(original.copy(), aug_name)

            frame_idx1 = NUM_FRAMES // 3
            frame_idx2 = 2 * NUM_FRAMES // 3

            if num_samples == 1:
                axes = axes.reshape(1, -1)

            axes[i, 0].imshow(original[frame_idx1])
            axes[i, 0].set_title(f'Original - Frame {frame_idx1}')
            axes[i, 0].axis('off')

            axes[i, 1].imshow(augmented[frame_idx1])
            axes[i, 1].set_title(f'Augmented - Frame {frame_idx1}')
            axes[i, 1].axis('off')

            axes[i, 2].imshow(original[frame_idx2])
            axes[i, 2].set_title(f'Original - Frame {frame_idx2}')
            axes[i, 2].axis('off')

            axes[i, 3].imshow(augmented[frame_idx2])
            axes[i, 3].set_title(f'Augmented - Frame {frame_idx2}')
            axes[i, 3].axis('off')

        plt.tight_layout()
        plt.show()

# %%
preview_individual_augmentations(videos_train, num_samples=2)
# Out:
# ============================================================
# Augmentation: Horizontal Flip
# ============================================================
# ============================================================
# Augmentation: Brightness
# ============================================================
# ============================================================
# Augmentation: Zoom
# ============================================================

# %% [markdown]
# ---
#
# # PART 8: COMBINED AUGMENTATION WITH PROBABILITIES

# %% [markdown]
# ### Apply Multiple Augmentations with Probabilities

# %%
# def apply_combined_augmentation(frames):
#     frames_uint8 = (frames * 255).astype(np.uint8)

#     # Spatial augmentations with probabilities
#     transform = A.ReplayCompose([
#         A.HorizontalFlip(p=0.5),
#         A.RandomBrightnessContrast(brightness_limit=0.3, p=0.4),
#         # A.Rotate(limit=15, p=0.3)
#         # A.RandomScale(scale_limit=0.2, p=0.3),
#     ])

#     # Apply to all frames consistently
#     data = transform(image=frames_uint8[0])
#     augmented = []
#     for frame in frames_uint8:
#         aug_frame = A.ReplayCompose.replay(data['replay'], image=frame)
#         augmented.append(aug_frame['image'].astype(np.float32) / 255.0)

#     augmented = np.array(augmented)

#     # Temporal crop (manual, not in albumentations)
#     if np.random.random() < 0.3:
#         augmented = augment_temporal_crop(augmented)

#     return augmented

# %%
def apply_combined_augmentation(frames, augment=True): # from other file (no Aug)
    """
    Apply augmentation to video frames
    frames: normalized float32 array (0-1)
    GUARANTEES output has same shape as input
    """
    if not augment:
        return frames

    input_shape = frames.shape

    # Convert to uint8 for Albumentations
    frames_uint8 = (frames * 255).astype(np.uint8)

    # Apply spatial augmentations consistently across all frames
    transform = get_augmentation_pipeline()
    data = transform(image=frames_uint8[0])

    augmented = []
    for frame in frames_uint8:
        aug_frame = A.ReplayCompose.replay(data['replay'], image=frame)
        augmented.append(aug_frame['image'].astype(np.float32) / 255.0)

    augmented = np.array(augmented)

    ## Apply temporal crop with probability
    # if np.random.random() < 0.3:
        # augmented = augment_temporal_crop(augmented)

    # CRITICAL: Ensure output shape matches input
    if augmented.shape != input_shape:
        print(f"ERROR: Shape mismatch in augmentation! Input: {input_shape}, Output: {augmented.shape}")
        # Force correct shape by padding/truncating
        if len(augmented) < input_shape[0]:
            # Pad
            padding = input_shape[0] - len(augmented)
            augmented = np.concatenate([augmented, np.repeat(augmented[-1:], padding, axis=0)], axis=0)
        elif len(augmented) > input_shape[0]:
            # Truncate
            augmented = augmented[:input_shape[0]]

    return augmented

# %% [markdown]
# ### Visualizing the Multiple Augmentations

# %%
# def visualize_combined_augmentation(X_train, num_samples=5):
#     """Visualize combined augmentation"""
#     print("\n" + "="*60)
#     print("Combined Augmentation Visualization")
#     print("="*60 + "\n")

#     fig, axes = plt.subplots(num_samples, 4, figsize=(16, num_samples * 3))

#     for i in range(num_samples):
#         idx = np.random.randint(0, len(X_train))
#         original = X_train[idx]
#         augmented = apply_combined_augmentation(original.copy())

#         frame_idx1 = NUM_FRAMES // 3
#         frame_idx2 = 2 * NUM_FRAMES // 3

#         if num_samples == 1:
#             axes = axes.reshape(1, -1)

#         axes[i, 0].imshow(original[frame_idx1])
#         axes[i, 0].set_title(f'Before - Frame {frame_idx1}')
#         axes[i, 0].axis('off')

#         axes[i, 1].imshow(augmented[frame_idx1])
#         axes[i, 1].set_title(f'After - Frame {frame_idx1}')
#         axes[i, 1].axis('off')

#         axes[i, 2].imshow(original[frame_idx2])
#         axes[i, 2].set_title(f'Before - Frame {frame_idx2}')
#         axes[i, 2].axis('off')

#         axes[i, 3].imshow(augmented[frame_idx2])
#         axes[i, 3].set_title(f'After - Frame {frame_idx2}')
#         axes[i, 3].axis('off')

#     plt.tight_layout()
#     plt.show()

# %%
# visualize_combined_augmentation(videos_train, num_samples=6)

# %% [markdown]
# ---
#
# # PART 9: APPLY AUGMENTATION TO TRAINING DATA

# %%
# def augment_dataset(X, y, augmentation_factor=1):
#     """
#     Apply augmentation to increase dataset size
#     augmentation_factor: how many augmented versions to create per sample (Video)
#     """
#     X_augmented = []
#     y_augmented = []

#     print("Applying augmentation to training data...")

#     # Keep original data
#     for i in range(len(X)):
#         X_augmented.append(X[i])
#         y_augmented.append(y[i])

#     # Add augmented versions
#     for _ in range(augmentation_factor):
#         for i in tqdm(range(len(X))):
#             augmented_frames = apply_combined_augmentation(X[i].copy())
#             X_augmented.append(augmented_frames)
#             y_augmented.append(y[i])

#     return np.array(X_augmented), np.array(y_augmented)

# %% [markdown]
# ### Fixed Function for the dimensions problem

# %%
def pad_videos_to_same_length(videos, target_frames=NUM_FRAMES):
    """
    Pad or truncate all videos to the same number of frames
    """
    padded_videos = []
    for video in videos:
        num_frames = len(video)
        if num_frames < target_frames:
            # Pad by repeating last frame
            padding_needed = target_frames - num_frames
            padding = np.repeat(video[-1:], padding_needed, axis=0)
            padded_video = np.concatenate([video, padding], axis=0)
        elif num_frames > target_frames:
            # Truncate by sampling evenly
            indices = np.linspace(0, num_frames - 1, target_frames, dtype=int)
            padded_video = video[indices]
        else:
            padded_video = video
        
        padded_videos.append(padded_video)
    
    return np.array(padded_videos)

# %% [markdown]
# ### Fixed augment function

# %%
def augment_dataset(X, y, augmentation_factor=1):
    """
    Apply augmentation to increase dataset size
    augmentation_factor: how many augmented versions to create per sample
    """
    X_augmented = []
    y_augmented = []
    
    print("Applying augmentation to training data...")
    
    # Keep original data
    for i in range(len(X)):
        X_augmented.append(X[i])
        y_augmented.append(y[i])
    
    # Add augmented versions
    for _ in range(augmentation_factor):
        for i in tqdm(range(len(X))):
            augmented_frames = apply_combined_augmentation(X[i].copy())
            X_augmented.append(augmented_frames)
            y_augmented.append(y[i])
    
    # DON'T convert to numpy array yet - keep as list
    return X_augmented, y_augmented  # Return lists, not np.array()

# %%
# Apply augmentation to training data (create 1 augmented version per sample)
videos_train_aug, labels_train_aug = augment_dataset(videos_train, labels_train, augmentation_factor=1)

print(f"\nOriginal training set size: {len(videos_train)}")
print(f"Augmented training set size: {len(videos_train_aug)}")
# Out:
# Applying augmentation to training data...
# 100%|██████████| 684/684 [00:39<00:00, 17.32it/s]
# Original training set size: 684
# Augmented training set size: 1368

# %% [markdown]
# ---
#
# # PART 10: BUILD CNN+RNN MODEL

# %% [markdown]
# ### Building the Model

# %%
def build_cnn_rnn_model(input_shape, num_classes):
    """
    Build CNN+RNN model for video classification
    Architecture: CNN (feature extraction) -> RNN (temporal modeling) -> Dense
    """
    inputs = layers.Input(shape=input_shape)

    # CNN Feature Extractor (applied to each frame via TimeDistributed)
    x = layers.TimeDistributed(
        layers.Conv2D(32, (3, 3), padding='same')
    )(inputs)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Activation('relu'))(x)
    x = layers.TimeDistributed(layers.MaxPooling2D((2, 2)))(x)
    x = layers.TimeDistributed(layers.Dropout(0.25))(x)

    x = layers.TimeDistributed(
        layers.Conv2D(64, (3, 3), padding='same')
    )(x)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Activation('relu'))(x)
    x = layers.TimeDistributed(layers.MaxPooling2D((2, 2)))(x)
    x = layers.TimeDistributed(layers.Dropout(0.25))(x)

    x = layers.TimeDistributed(
        layers.Conv2D(128, (3, 3), padding='same')
    )(x)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Activation('relu'))(x)
    x = layers.TimeDistributed(layers.MaxPooling2D((2, 2)))(x)
    x = layers.TimeDistributed(layers.Dropout(0.3))(x)

    x = layers.TimeDistributed(
        layers.Conv2D(256, (3, 3), padding='same')
    )(x)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Activation('relu'))(x)
    x = layers.TimeDistributed(layers.MaxPooling2D((2, 2)))(x)
    x = layers.TimeDistributed(layers.Dropout(0.3))(x)

    # Flatten CNN output for each timestep
    x = layers.TimeDistributed(layers.Flatten())(x)

    # Dense layer after CNN features
    x = layers.TimeDistributed(layers.Dense(512))(x)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Activation('relu'))(x)
    x = layers.TimeDistributed(layers.Dropout(0.4))(x)

    # RNN layers (LSTM for temporal modeling)
    x = layers.LSTM(256, return_sequences=True)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)

    x = layers.LSTM(128, return_sequences=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)

    # Dense layers for classification
    x = layers.Dense(128)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(64)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.5)(x)

    ## Output layer (softmax, multi classification)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    ## Output Layer (sigmoid, binary classification)
    # outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    return model

# %%
input_shape = (NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, CHANNELS)

nn_model = build_cnn_rnn_model(input_shape, NUM_CLASSES)
# Out:
# I0000 00:00:1760542469.808839      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1760542469.809506      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
print("Model built successfully!")
nn_model.summary()
# Out:
# Model built successfully!
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 50, 64, 64, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 50, 64, 64, 32) │           896 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 50, 64, 64, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 50, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 50, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 50, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 50, 32, 32, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 50, 32, 32, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 50, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_8              │ (None, 50, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 50, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_10             │ (None, 50, 16, 16,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_11             │ (None, 50, 16, 16,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_12             │ (None, 50, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 50, 8, 8, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_14             │ (None, 50, 8, 8, 128)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_15             │ (None, 50, 8, 8, 256)  │       295,168 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 50, 8, 8, 256)  │         1,024 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 50, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_18             │ (None, 50, 4, 4, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_19             │ (None, 50, 4, 4, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_20             │ (None, 50, 4096)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 50, 512)        │     2,097,664 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 50, 512)        │         2,048 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 50, 512)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_24             │ (None, 50, 512)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 50, 256)        │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 50, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 50, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,501,826 (13.36 MB)
#  Trainable params: 3,498,690 (13.35 MB)
#  Non-trainable params: 3,136 (12.25 KB)

# %% [markdown]
# ### Compile the Model

# %%
nn_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **for sigmoid (binary classification)**

# %%
# @title
# nn_model.compile(
#     optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
#     loss='binary_crossentropy',
#     metrics=['accuracy']
# )

# %% [markdown]
# ---
#
# # PART 11: SETUP CALLBACKS AND TRAIN MODEL

# %%
# Create directory for saving models
os.makedirs('/kaggle/working/models', exist_ok=True)

# %%
# Define callbacks
checkpoint = ModelCheckpoint(
    '/kaggle/working/models/best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# %%
callbacks = [checkpoint, reduce_lr, early_stopping]

# %% [markdown]
# For **softmax only**
#
# Comment for **sigmoid**

# %%
## Convert labels to categorical for training (softmax, not needed for sigmoid, I used sparse categorical crossentropy, so I don't need to OHE the label)
# y_train_cat = to_categorical(labels_train_aug, num_classes=NUM_CLASSES)

# %%
# Train the model
# print("\nStarting training...")
# nn_model_fit = nn_model.fit(
#     videos_train_aug, labels_train_aug,
#     batch_size=BATCH_SIZE,
#     epochs=EPOCHS,
#     validation_split=0.2,
#     callbacks=callbacks,
#     shuffle=True,
#     verbose=1
# )

# print("\nTraining completed!")

# %% [markdown]
# ### Conversion to numpy before training

# %%
# Train the model
print("\nStarting training...")

# Pad videos to same length before training
print("Padding videos to uniform length...")
videos_train_aug_padded = pad_videos_to_same_length(videos_train_aug, target_frames=NUM_FRAMES)
labels_train_aug_array = np.array(labels_train_aug)

print(f"Padded training shape: {videos_train_aug_padded.shape}")

nn_model_fit = nn_model.fit(
    np.array(videos_train_aug), np.array(labels_train_aug),  # Convert to numpy here during fit
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.2,
    callbacks=callbacks,
    verbose=1
)

print("\nTraining completed!")
# Out:
# Starting training...
# Padding videos to uniform length...
# Padded training shape: (1368, 50, 64, 64, 3)
# Epoch 1/50
# I0000 00:00:1760542723.784475    6949 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.5509 - loss: 0.8970
# Epoch 1: val_accuracy improved from -inf to 0.56569, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 324s 640ms/step - accuracy: 0.5509 - loss: 0.8968 - val_accuracy: 0.5657 - val_loss: 0.7120 - learning_rate: 0.0010
# Epoch 2/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - accuracy: 0.5703 - loss: 0.7950
# Epoch 2: val_accuracy did not improve from 0.56569
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 559ms/step - accuracy: 0.5703 - loss: 0.7948 - val_accuracy: 0.5657 - val_loss: 0.7532 - learning_rate: 0.0010
# Epoch 3/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.6195 - loss: 0.7221
# Epoch 3: val_accuracy did not improve from 0.56569
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.6195 - loss: 0.7221 - val_accuracy: 0.5657 - val_loss: 0.6980 - learning_rate: 0.0010
# Epoch 4/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.5983 - loss: 0.6752
# Epoch 4: val_accuracy did not improve from 0.56569
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.5984 - loss: 0.6751 - val_accuracy: 0.5657 - val_loss: 0.7495 - learning_rate: 0.0010
# Epoch 5/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.6602 - loss: 0.6249
# Epoch 5: val_accuracy improved from 0.56569 to 0.56934, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 559ms/step - accuracy: 0.6602 - loss: 0.6249 - val_accuracy: 0.5693 - val_loss: 0.6570 - learning_rate: 0.0010
# Epoch 6/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7187 - loss: 0.5662
# Epoch 6: val_accuracy did not improve from 0.56934
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.7188 - loss: 0.5662 - val_accuracy: 0.5657 - val_loss: 0.6734 - learning_rate: 0.0010
# Epoch 7/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.6993 - loss: 0.5823
# Epoch 7: val_accuracy improved from 0.56934 to 0.61679, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.6994 - loss: 0.5822 - val_accuracy: 0.6168 - val_loss: 0.6465 - learning_rate: 0.0010
# Epoch 8/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7239 - loss: 0.5325
# Epoch 8: val_accuracy improved from 0.61679 to 0.67518, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.7239 - loss: 0.5325 - val_accuracy: 0.6752 - val_loss: 0.5850 - learning_rate: 0.0010
# Epoch 9/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7781 - loss: 0.4995
# Epoch 9: val_accuracy did not improve from 0.67518
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.7781 - loss: 0.4996 - val_accuracy: 0.5657 - val_loss: 0.7029 - learning_rate: 0.0010
# Epoch 10/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7663 - loss: 0.5326
# Epoch 10: val_accuracy did not improve from 0.67518
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.7661 - loss: 0.5326 - val_accuracy: 0.6204 - val_loss: 0.8803 - learning_rate: 0.0010
# Epoch 11/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7361 - loss: 0.5459
# Epoch 11: val_accuracy did not improve from 0.67518
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.7362 - loss: 0.5457 - val_accuracy: 0.5693 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 12/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7695 - loss: 0.4516
# Epoch 12: val_accuracy improved from 0.67518 to 0.67883, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.7695 - loss: 0.4516 - val_accuracy: 0.6788 - val_loss: 0.5700 - learning_rate: 0.0010
# Epoch 13/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7861 - loss: 0.4882
# Epoch 13: val_accuracy did not improve from 0.67883
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.7860 - loss: 0.4882 - val_accuracy: 0.5730 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 14/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7591 - loss: 0.4952
# Epoch 14: val_accuracy did not improve from 0.67883
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.7591 - loss: 0.4952 - val_accuracy: 0.6569 - val_loss: 0.6352 - learning_rate: 0.0010
# Epoch 15/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7918 - loss: 0.4742
# Epoch 15: val_accuracy did not improve from 0.67883
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.7919 - loss: 0.4741 - val_accuracy: 0.6642 - val_loss: 0.6113 - learning_rate: 0.0010
# Epoch 16/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7831 - loss: 0.4992
# Epoch 16: val_accuracy improved from 0.67883 to 0.75547, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.7831 - loss: 0.4990 - val_accuracy: 0.7555 - val_loss: 0.5923 - learning_rate: 0.0010
# Epoch 17/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7940 - loss: 0.4302
# Epoch 17: val_accuracy did not improve from 0.75547
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.7940 - loss: 0.4303 - val_accuracy: 0.6204 - val_loss: 0.6067 - learning_rate: 0.0010
# Epoch 18/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8170 - loss: 0.4183
# Epoch 18: val_accuracy did not improve from 0.75547
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.8171 - loss: 0.4182 - val_accuracy: 0.7080 - val_loss: 0.5069 - learning_rate: 5.0000e-04
# Epoch 19/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8207 - loss: 0.4075
# Epoch 19: val_accuracy improved from 0.75547 to 0.75912, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.8207 - loss: 0.4075 - val_accuracy: 0.7591 - val_loss: 0.5140 - learning_rate: 5.0000e-04
# Epoch 20/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8273 - loss: 0.4056
# Epoch 20: val_accuracy improved from 0.75912 to 0.78467, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.8273 - loss: 0.4055 - val_accuracy: 0.7847 - val_loss: 0.4713 - learning_rate: 5.0000e-04
# Epoch 21/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8224 - loss: 0.4003
# Epoch 21: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8224 - loss: 0.4003 - val_accuracy: 0.7299 - val_loss: 0.4972 - learning_rate: 5.0000e-04
# Epoch 22/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8999 - loss: 0.3123
# Epoch 22: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8998 - loss: 0.3125 - val_accuracy: 0.6277 - val_loss: 1.2016 - learning_rate: 5.0000e-04
# Epoch 23/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8573 - loss: 0.3856
# Epoch 23: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8573 - loss: 0.3856 - val_accuracy: 0.6788 - val_loss: 0.5751 - learning_rate: 5.0000e-04
# Epoch 24/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8842 - loss: 0.3801
# Epoch 24: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8842 - loss: 0.3801 - val_accuracy: 0.6387 - val_loss: 0.7513 - learning_rate: 5.0000e-04
# Epoch 25/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8748 - loss: 0.3464
# Epoch 25: val_accuracy did not improve from 0.78467
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.8747 - loss: 0.3465 - val_accuracy: 0.6788 - val_loss: 0.5180 - learning_rate: 5.0000e-04
# Epoch 26/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8923 - loss: 0.3092
# Epoch 26: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8923 - loss: 0.3092 - val_accuracy: 0.5620 - val_loss: 0.6848 - learning_rate: 2.5000e-04
# Epoch 27/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8557 - loss: 0.3570
# Epoch 27: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8558 - loss: 0.3569 - val_accuracy: 0.7080 - val_loss: 0.5160 - learning_rate: 2.5000e-04
# Epoch 28/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8951 - loss: 0.2701
# Epoch 28: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8951 - loss: 0.2701 - val_accuracy: 0.5912 - val_loss: 0.6571 - learning_rate: 2.5000e-04
# Epoch 29/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9020 - loss: 0.2519
# Epoch 29: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9020 - loss: 0.2520 - val_accuracy: 0.6460 - val_loss: 0.5109 - learning_rate: 2.5000e-04
# Epoch 30/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.9155 - loss: 0.2601
# Epoch 30: val_accuracy did not improve from 0.78467
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9154 - loss: 0.2601 - val_accuracy: 0.6715 - val_loss: 0.5361 - learning_rate: 2.5000e-04
# Epoch 31/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9330 - loss: 0.2128
# Epoch 31: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9330 - loss: 0.2129 - val_accuracy: 0.6314 - val_loss: 0.5995 - learning_rate: 1.2500e-04
# Epoch 32/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9238 - loss: 0.2335
# Epoch 32: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9237 - loss: 0.2336 - val_accuracy: 0.7701 - val_loss: 0.4310 - learning_rate: 1.2500e-04
# Epoch 33/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.9343 - loss: 0.2610
# Epoch 33: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9343 - loss: 0.2610 - val_accuracy: 0.7555 - val_loss: 0.4449 - learning_rate: 1.2500e-04
# Epoch 34/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9261 - loss: 0.2227
# Epoch 34: val_accuracy did not improve from 0.78467
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9261 - loss: 0.2227 - val_accuracy: 0.7080 - val_loss: 0.4820 - learning_rate: 1.2500e-04
# Epoch 35/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9260 - loss: 0.2408
# Epoch 35: val_accuracy improved from 0.78467 to 0.85766, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 558ms/step - accuracy: 0.9260 - loss: 0.2408 - val_accuracy: 0.8577 - val_loss: 0.3550 - learning_rate: 1.2500e-04
# Epoch 36/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9398 - loss: 0.2170
# Epoch 36: val_accuracy did not improve from 0.85766
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9398 - loss: 0.2170 - val_accuracy: 0.7482 - val_loss: 0.5721 - learning_rate: 1.2500e-04
# Epoch 37/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9394 - loss: 0.1985
# Epoch 37: val_accuracy did not improve from 0.85766
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9394 - loss: 0.1985 - val_accuracy: 0.7737 - val_loss: 0.4545 - learning_rate: 1.2500e-04
# Epoch 38/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9484 - loss: 0.1778
# Epoch 38: val_accuracy did not improve from 0.85766
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9484 - loss: 0.1779 - val_accuracy: 0.7518 - val_loss: 0.6016 - learning_rate: 1.2500e-04
# Epoch 39/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9346 - loss: 0.1906
# Epoch 39: val_accuracy did not improve from 0.85766
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9346 - loss: 0.1906 - val_accuracy: 0.7372 - val_loss: 0.6259 - learning_rate: 1.2500e-04
# Epoch 40/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.8988 - loss: 0.2906
# Epoch 40: val_accuracy did not improve from 0.85766
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.8988 - loss: 0.2905 - val_accuracy: 0.8139 - val_loss: 0.4109 - learning_rate: 1.2500e-04
# Epoch 41/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.9480 - loss: 0.1574
# Epoch 41: val_accuracy improved from 0.85766 to 0.86131, saving model to /kaggle/working/models/best_model.keras
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9479 - loss: 0.1574 - val_accuracy: 0.8613 - val_loss: 0.3684 - learning_rate: 6.2500e-05
# Epoch 42/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9397 - loss: 0.1925
# Epoch 42: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9397 - loss: 0.1926 - val_accuracy: 0.7883 - val_loss: 0.5060 - learning_rate: 6.2500e-05
# Epoch 43/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9517 - loss: 0.2032
# Epoch 43: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9517 - loss: 0.2032 - val_accuracy: 0.8285 - val_loss: 0.4239 - learning_rate: 6.2500e-05
# Epoch 44/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.9442 - loss: 0.2211
# Epoch 44: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9442 - loss: 0.2210 - val_accuracy: 0.7847 - val_loss: 0.5372 - learning_rate: 6.2500e-05
# Epoch 45/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9629 - loss: 0.1464
# Epoch 45: val_accuracy did not improve from 0.86131
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9629 - loss: 0.1464 - val_accuracy: 0.7847 - val_loss: 0.5802 - learning_rate: 6.2500e-05
# Epoch 46/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9384 - loss: 0.1910
# Epoch 46: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 153s 557ms/step - accuracy: 0.9384 - loss: 0.1909 - val_accuracy: 0.7956 - val_loss: 0.5322 - learning_rate: 3.1250e-05
# Epoch 47/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9530 - loss: 0.1923
# Epoch 47: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9530 - loss: 0.1922 - val_accuracy: 0.7774 - val_loss: 0.6341 - learning_rate: 3.1250e-05
# Epoch 48/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9450 - loss: 0.2366
# Epoch 48: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9450 - loss: 0.2364 - val_accuracy: 0.8212 - val_loss: 0.5227 - learning_rate: 3.1250e-05
# Epoch 49/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9377 - loss: 0.2417
# Epoch 49: val_accuracy did not improve from 0.86131
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 557ms/step - accuracy: 0.9378 - loss: 0.2415 - val_accuracy: 0.7664 - val_loss: 0.6537 - learning_rate: 3.1250e-05
# Epoch 50/50
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.9640 - loss: 0.1447
# Epoch 50: val_accuracy did not improve from 0.86131
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 152s 556ms/step - accuracy: 0.9640 - loss: 0.1449 - val_accuracy: 0.7847 - val_loss: 0.5371 - learning_rate: 3.1250e-05
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 35.
#
# Training completed!

# %% [markdown]
# ---
#
# # PART 12: PLOT TRAINING HISTORY

# %%
def plot_training_history(model):
    """
    Plot accuracy and loss curves
    """
    # Plot Accuracy
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(model.history['accuracy'], label='Training Accuracy', linewidth=2, color="blue")
    plt.plot(model.history['val_accuracy'], label='Validation Accuracy', linewidth=2, color="green")
    plt.title('Model Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(model.history['loss'], label='Training Loss', linewidth=2, color="red")
    plt.plot(model.history['val_loss'], label='Validation Loss', linewidth=2, color="orange")
    plt.title('Model Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
## Plot training history
plot_training_history(nn_model_fit)

# %% [markdown]
# ---
#
# # PART 13: EVALUATE MODEL ON TEST SET

# %%
# Load best model
nn_model.load_weights('/kaggle/working/models/best_model.keras')

# %%
# Make predictions on test set
print("Making predictions on test set...")
labels_pred_probs = nn_model.predict(videos_test, batch_size=BATCH_SIZE)

## Softmax
labels_pred = np.argmax(labels_pred_probs, axis=1)

## Sigmoid
# labels_pred = (labels_pred_probs > 0.5).astype(int).flatten()  # Change from argmax

print("Predictions completed!")
# Out:
# Making predictions on test set...
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 370ms/step
# Predictions completed!

# %% [markdown]
# ---
#
# # PART 14: CLASSIFICATION REPORT AND METRICS

# %%
# Calculate metrics
accuracy = accuracy_score(labels_test, labels_pred)
precision = precision_score(labels_test, labels_pred, average='weighted')
recall = recall_score(labels_test, labels_pred, average='weighted')
f1 = f1_score(labels_test, labels_pred, average='weighted')

# %%
print("\n" + "="*60)
print("MODEL EVALUATION METRICS")
print("="*60)
print(f"\nAccuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# ============================================================
# MODEL EVALUATION METRICS
# ============================================================
#
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-Score:  1.0000

# %%
print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(labels_test, labels_pred, target_names=CLASS_NAMES))
# Out:
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#                 precision    recall  f1-score   support
#
# non_shoplifter       1.00      1.00      1.00       106
#     shoplifter       1.00      1.00      1.00        65
#
#       accuracy                           1.00       171
#      macro avg       1.00      1.00      1.00       171
#   weighted avg       1.00      1.00      1.00       171

# %% [markdown]
# ---
#
# # PART 15: CONFUSION MATRIX VISUALIZATION

# %%
## Compute confusion matrix
cm = confusion_matrix(labels_test, labels_pred)

## Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASS_NAMES,
            yticklabels=CLASS_NAMES,
            cbar_kws={'label': 'Count'},
            annot_kws={'size': 16})
plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
plt.ylabel('True Label', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Print confusion matrix values
print("\nConfusion Matrix:")
print(cm)
print(f"\nTrue Negatives:  {cm[0, 0]}")
print(f"False Positives: {cm[0, 1]}")
print(f"False Negatives: {cm[1, 0]}")
print(f"True Positives:  {cm[1, 1]}")
# Out:
# Confusion Matrix:
# [[106   0]
#  [  0  65]]
#
# True Negatives:  106
# False Positives: 0
# False Negatives: 0
# True Positives:  65

# %% [markdown]
# ---
#
# # PART 16: SAMPLE PREDICTIONS VISUALIZATION

# %%
def visualize_predictions(X_test, y_test, y_pred, num_samples=6):
    """
    Visualize sample predictions with ground truth and predicted labels
    """
    indices = np.random.choice(len(X_test), num_samples, replace=False)

    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.ravel()

    for i, idx in enumerate(indices):
        # Get middle frame from video
        frame = X_test[idx][NUM_FRAMES // 2]
        true_label = CLASS_NAMES[y_test[idx]]
        pred_label = CLASS_NAMES[y_pred[idx]]

        # Determine if prediction is correct
        color = 'green' if y_test[idx] == y_pred[idx] else 'red'

        axes[i].imshow(frame)
        axes[i].set_title(f'True: {true_label}\nPredicted: {pred_label}',
                         color=color, fontweight='bold', fontsize=12)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
# Visualize sample predictions
print("\n" + "="*60)
print("SAMPLE PREDICTIONS")
print("="*60)
visualize_predictions(videos_test, labels_test, labels_pred, num_samples=6)
# Out:
# ============================================================
# SAMPLE PREDICTIONS
# ============================================================

# %% [markdown]
# ---
